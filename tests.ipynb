# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf 
from generators import linemod
from absl import app, flags
import matplotlib.pyplot as plt
import numpy as np

# %%
FLAGS = flags.FLAGS
args = ["dummy"]
FLAGS(args)
# Out:
# ['dummy']

# %% [markdown]
# #### Explore dataset

# %%
lm_data = linemod.LineModGenerator(
    FLAGS.linemod_path, 
    FLAGS.object_id, 
    rotation_representation='axis_angle', 
    batch_size=1, 
    use_colorspace_augmentation=True,
    use_6DoF_augmentation= True)

# %%
d_iter = iter(lm_data)
d = next(d_iter)

# %%
d = next(d_iter)
x,y = d 
image = x[0]
K = x[1] #intrinsics

image = image * [0.229, 0.224, 0.225]
image += [0.485, 0.456, 0.406]
image *= 255
plt.imshow(image.astype(np.int32)[0, ...])
plt.show()
